# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
HospInfo = pd.read_csv('HospInfo.csv')

# %%
plt.plot(HospInfo.Provider_ID/10**6,HospInfo.ZIPCode/10**6)
plt.show()

# %%
plt.bar(HospInfo.Address,HospInfo.Provider_ID/10**6)
plt.show()

# %%
plt.bar(HospInfo.Hospital_Name,HospInfo.Provider_ID/10**6)
plt.show()
